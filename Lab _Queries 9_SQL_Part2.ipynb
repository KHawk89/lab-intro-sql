# %%
import pymysql
from sqlalchemy import create_engine
import pandas as pd
import getpass  # to get the password without showing the input
password = getpass.getpass()
# Out:
# ········

# %%
connection_string = 'mysql+pymysql://root:' + password + '@localhost/bank'
engine = create_engine(connection_string)
rm = pd.read_sql_query('SELECT * FROM sakila.rentals_may', engine)

# %%
rj = pd.read_sql_query('SELECT * FROM sakila.rentals_june', engine)
rj
# Out:
#       rental_id         rental_date  inventory_id  customer_id  \
# 0          1158 2005-06-14 22:53:33          1632          416
# 1          1159 2005-06-14 22:55:13          4395          516
# 2          1160 2005-06-14 23:00:34          2795          239
# 3          1161 2005-06-14 23:07:08          1690          285
# 4          1162 2005-06-14 23:09:38           987          310
# ...         ...                 ...           ...          ...
# 2306       3465 2005-06-21 22:10:01          1488          510
# 2307       3466 2005-06-21 22:13:33           371          226
# 2308       3467 2005-06-21 22:19:25           729          543
# 2309       3468 2005-06-21 22:43:45          2899          100
# 2310       3469 2005-06-21 22:48:59          4087          181
#
#              return_date  staff_id         last_update
# 0    2005-06-18 21:37:33         2 2006-02-15 21:30:53
# 1    2005-06-17 02:11:13         1 2006-02-15 21:30:53
# ...

# %%
p = rm.merge(rj, how='cross')
p
# Out:
#          rental_id_x       rental_date_x  inventory_id_x  customer_id_x  \
# 0                  1 2005-05-24 22:53:30             367            130
# 1                  1 2005-05-24 22:53:30             367            130
# 2                  1 2005-05-24 22:53:30             367            130
# 3                  1 2005-05-24 22:53:30             367            130
# 4                  1 2005-05-24 22:53:30             367            130
# ...              ...                 ...             ...            ...
# 2671511         1157 2005-05-31 22:47:45            1449             61
# 2671512         1157 2005-05-31 22:47:45            1449             61
# 2671513         1157 2005-05-31 22:47:45            1449             61
# 2671514         1157 2005-05-31 22:47:45            1449             61
# 2671515         1157 2005-05-31 22:47:45            1449             61
#
#               return_date_x  staff_id_x       last_update_x  rental_id_y  \
# ...

# %%
def molf(x, y):
    z = x.merge(y, how='cross')
    if z['rental_id_x'].nunique() > z['rental_id_y'].nunique():
        return print('There were more rentals in may')
    else:
        return print('There were more rentals in june')

# %%
molf(rm, rj)
# Out:
# There were more rentals in june
